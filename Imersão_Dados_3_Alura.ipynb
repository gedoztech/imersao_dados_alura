# %% [markdown]
# <a href="https://colab.research.google.com/github/johnnyglauber/imersao_dados_alura/blob/main/Imers%C3%A3o_Dados_3_Alura.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Imersão Dados Alura 3ª Edição

# %% [markdown]
# # Aula 1 - Análise de dados, python, pandas e novos fármacos

# %%
# Importando bibliotecas
import pandas as pd
import matplotlib.pyplot as plt

# Lendo arquivo remoto através de URL e mostrando os dados
dados_url = 'https://github.com/alura-cursos/imersaodados3/blob/main/dados/dados_experimentos.zip?raw=true'
dados = pd.read_csv(dados_url, compression = 'zip') 
dados
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0      id_000644bb2     com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc     com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a     com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3      id_0015fd391     com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4      id_001626bd3     com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# ...

# %%
# Mostrando valores únicos da coluna tratamento
dados['tratamento'].unique()
# Out:
# array(['com_droga', 'com_controle'], dtype=object)

# %%
# Mostrando totais de registros para cada valor único da coluna tratamento
dados['tratamento'].value_counts()
# Out:
# com_droga       21948
# com_controle     1866
# Name: tratamento, dtype: int64

# %%
# Mostrando as 5 primeiras linhas do arquivo
dados.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %%
# Mostrando totais de registros de forma normalizada
# Para cada valor único da coluna dose
dados['dose'].value_counts(normalize = True)
# Out:
# D1    0.510078
# D2    0.489922
# Name: dose, dtype: float64

# %% [markdown]
# # Desafios Aula 1
#
# ### 1) Por que os dados da coluna tratamento são tão desbalanceados
#
# - A coluna tratamento possui 92% dos dados com valor com_droga e 8% com valor com_controle.
# - Apenas 1 tipo de droga foi utilizada no grupo controle, sendo os demais 3288 tipos de droga aplicados no grupo experimental
# - Os dados da coluna tratamento estão desbalanceados pois para o grupo controle é necessário apenas 1 droga? E assim, cruzando os dados das drogas com os de tratamento, os dados não ficam tão desbalanceados?
#
# ### 2) Plotar as 5 últimas linhas da tabela
# - reposta nas células de código abaixo
#
# ### 3) Calcular a proporção da coluna tratamento
# - reposta nas células de código abaixo
#
# ### 4) Quantos tipos de drogas foram investigadas?
# - reposta nas células de código abaixo
#
# ### 5) Procurar na documentação o método query do pandas
# - reposta nas células de código abaixo
#
# ### 6) Renomear as colunas tirando o hífen
# - reposta nas células de código abaixo
#
# ### 7) Deixar os gráficos mais bonitões
# - reposta nas células de código abaixo
#
# ### 8) Resumo do que você aprendeu na aula
# - Iniciei aprendizado na ferramenta Colab e em análise de dados
# - Aprendi comandos python e bilbioteca pandas para análise de dados
# - Aprendi biblioteca matplotlib para geração de gráficos
# - Aprendi sobre exploração de dados
# - Aprendi um pouco sobre biologia molecular
# - Aprendi sobre pesquisa experimental

# %%
# Desafio 1 => tentando responder
# Cruzando dados das colunas tratamento e droga
dados.groupby(['tratamento', 'droga']).size()
# Out:
# tratamento    droga
# com_controle  cacb2b860    1866
# com_droga     00199ff52       6
#               00251fc41       6
#               00321ea80      12
#               0034c0847       6
#                            ...
#               ff9565933       6
#               ffd66e220       6
#               ffe357f8f       1
#               ffed8e1c9       6
#               fff7d208d       6
# Length: 3289, dtype: int64

# %%
 # Desafio 1 => tentando responder
 # Cruzando dados das colunas tratamento, dose e tempo
 dados.groupby(['tratamento', 'dose', 'tempo']).size()
# Out:
# tratamento    dose  tempo
# com_controle  D1    24        301
#                     48        343
#                     72        307
#               D2    24        305
#                     48        305
#                     72        305
# com_droga     D1    24       3585
#                     48       4011
#                     72       3600
#               D2    24       3581
#                     48       3591
#                     72       3580
# dtype: int64

# %%
 # Desafio 1 => tentando responder
 # Cruzando dados das colunas tratamento, droga, dose e tempo
 dados.groupby(['tratamento', 'droga', 'dose', 'tempo']).size()
# Out:
# tratamento    droga      dose  tempo
# com_controle  cacb2b860  D1    24       301
#                                48       343
#                                72       307
#                          D2    24       305
#                                48       305
#                                        ...
# com_droga     fff7d208d  D1    48         1
#                                72         1
#                          D2    24         1
#                                48         1
#                                72         1
# Length: 18995, dtype: int64

# %%
# Desafio 2 => mostrando as 5 últimas linhas do arquivo
dados.tail()
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# 23813  id_ffffdd77b     com_droga     72   D1  ... -3.5770 -0.4775 -2.1500 -4.2520
#
# [5 rows x 877 columns]

# %%
# Desafio 3 => mostrando proporção da coluna tratamento
dados['tratamento'].value_counts(normalize = True)
# Out:
# com_droga       0.921643
# com_controle    0.078357
# Name: tratamento, dtype: float64

# %%
# Desafio 4 => mostrando total de tipos de droga utilizados
len(dados['droga'].unique())
# Out:
# 3289

# %%
# Desafio 5 => utilizando método query
dados.query('`g-0` > 0')
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0      id_000644bb2     com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc     com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a     com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 6      id_001bd861f     com_droga     24   D2  ...  2.4670  0.0357  0.1351 -0.3179
# 7      id_0020d0484     com_droga     48   D1  ...  0.6633  0.4562 -0.9622  0.0260
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23807  id_fff7e6992     com_droga     48   D1  ...  0.3738  0.8636  0.4494  0.1218
# 23808  id_fff8c2444     com_droga     72   D1  ... -0.7415  0.8413 -0.4259  0.2434
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# ...

# %%
# Desafio 6 => removendo os hífens dos nomes das colunas
dados.columns = dados.columns.str.replace('-', '')
dados.columns
# Out:
# Index(['id', 'tratamento', 'tempo', 'dose', 'droga', 'g0', 'g1', 'g2', 'g3',
#        'g4',
#        ...
#        'c90', 'c91', 'c92', 'c93', 'c94', 'c95', 'c96', 'c97', 'c98', 'c99'],
#       dtype='object', length=877)

# %%
# Desafio 7 => gráficos com título e labels
plt.figure(figsize=(5,5))
plt.pie(dados['tempo'].value_counts(), explode=(0.01, 0.01, 0.01), labels=[72, 48, 24], autopct='%1.1f%%')
plt.title('Tempo de Ação da Droga')
plt.show()

# %% [markdown]
# # Aula 2 - Estatísticas, visualizações de dados e distribuições

# %%
# Renomeando a coluna droga para composto
mapa = {'droga': 'composto'}
dados.rename(columns=mapa, inplace=True)

# %%
# Mostrando 5 primeiras linhas para conferir a mudança da coluna
dados.head()
# Out:
#              id tratamento  tempo dose  ...     c96     c97     c98     c99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %%
# Mostrando os nomes dos 5 compostos com maior frequência
cod_compostos = dados['composto'].value_counts().index[:5]
cod_compostos
# Out:
# Index(['cacb2b860', '87d714366', '9f80f3f77', '8b87a7a83', '5628cb3ee'], dtype='object')

# %%
# Mostrando os dados da tabela filtrados pelos 5 compostos com maior frequência
dados_compostos = dados.query('composto in @cod_compostos')
dados_compostos
# Out:
#                  id    tratamento  tempo dose  ...     c96     c97     c98     c99
# 7      id_0020d0484     com_droga     48   D1  ...  0.6633  0.4562 -0.9622  0.0260
# 16     id_002fb9c19     com_droga     48   D1  ... -9.9840 -9.9840 -9.9840 -6.7840
# 25     id_0054388ec  com_controle     48   D1  ...  0.8837  0.5534  0.8976  1.0050
# 38     id_0079af0fb  com_controle     24   D1  ...  0.2187  0.0737  0.6498 -1.4820
# 40     id_007bfbb91  com_controle     24   D2  ... -0.5751  0.3362  0.8543  0.9180
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23793  id_ffd26f361  com_controle     48   D2  ...  0.8813  0.7757 -0.5272  0.7082
# 23802  id_fff3976bd     com_droga     24   D1  ... -8.4480 -4.4550 -5.7930 -3.7000
# 23805  id_fff6df1c5     com_droga     48   D2  ...  0.1516  0.4503 -0.6312 -0.8302
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# ...

# %%
#Importando biblioteca
import seaborn as sns

# Carregando configurações padrões do seaborn
sns.set()

# Aumentando o tamnaho da imagem através do matplotlib
plt.figure(figsize=(8, 6))

# Criando gráfico utilizando o seaborn
ax = sns.countplot(x='composto', data=dados_compostos)

# Configurando título e mostrando o gráfico
ax.set_title('Top 5 Compostos')

# Removendo texto de fora da figura
plt.show()

# %%
# Mostrando histograma da coluna g0 com alteração da escala dos valores
dados['g0'].hist(bins=100)

# %%
# Mostrando histograma da coluna g19 com alteração da escala dos valores
# Para comparar com g0
dados['g19'].hist(bins=100)

# %%
# Mostrando a média dos dados da coluna g0
dados['g0'].mean()
# Out:
# 0.24836629293692816

# %%
# Mostrando dados estatísticos utilizando comando do pandas
dados.describe()
# Out:
#               tempo            g0  ...           c98           c99
# count  23814.000000  23814.000000  ...  23814.000000  23814.000000
# mean      48.020156      0.248366  ...     -0.470252     -0.301505
# std       19.402807      1.393399  ...      1.834828      1.407918
# min       24.000000     -5.513000  ...    -10.000000    -10.000000
# 25%       24.000000     -0.473075  ...     -0.592600     -0.562900
# 50%       48.000000     -0.008850  ...      0.014000     -0.019500
# 75%       72.000000      0.525700  ...      0.461275      0.438650
# max       72.000000     10.000000  ...      3.111000      3.805000
#
# [8 rows x 873 columns]

# %%
# Mostrando dados estatísticos das colunas que vão de g0 a g771 (todos os genes)
dados.loc[:, 'g0':'g771'].describe()
# Out:
#                  g0            g1  ...          g770          g771
# count  23814.000000  23814.000000  ...  23814.000000  23814.000000
# mean       0.248366     -0.095684  ...     -0.219210      0.101524
# std        1.393399      0.812363  ...      1.326193      1.417674
# min       -5.513000     -5.737000  ...    -10.000000    -10.000000
# 25%       -0.473075     -0.562200  ...     -0.554400     -0.523800
# 50%       -0.008850     -0.046600  ...      0.028700     -0.006500
# 75%        0.525700      0.403075  ...      0.496400      0.536950
# max       10.000000      5.039000  ...     10.000000     10.000000
#
# [8 rows x 772 columns]

# %%
# Alternando colunas e linhas
dados.loc[:, 'g0':'g771'].describe().T
# Out:
#         count      mean       std     min       25%      50%       75%     max
# g0    23814.0  0.248366  1.393399  -5.513 -0.473075 -0.00885  0.525700  10.000
# g1    23814.0 -0.095684  0.812363  -5.737 -0.562200 -0.04660  0.403075   5.039
# g2    23814.0  0.152253  1.035731  -9.104 -0.437750  0.07520  0.663925   8.257
# g3    23814.0  0.081971  0.950012  -5.998 -0.429575  0.00805  0.463400  10.000
# g4    23814.0  0.057347  1.032091  -6.369 -0.470925 -0.02690  0.465375  10.000
# ...       ...       ...       ...     ...       ...      ...       ...     ...
# g767  23814.0 -0.076251  1.115477 -10.000 -0.506200  0.00990  0.511175   6.317
# g768  23814.0  0.134162  0.951264  -4.269 -0.353100  0.00540  0.409075  10.000
# g769  23814.0 -0.128018  1.230636 -10.000 -0.544600  0.00060  0.498500   5.911
# g770  23814.0 -0.219210  1.326193 -10.000 -0.554400  0.02870  0.496400  10.000
# g771  23814.0  0.101524  1.417674 -10.000 -0.523800 -0.00650  0.536950  10.000
#
# [772 rows x 8 columns]

# %%
# Mostrando histograma de todas as médias de todos os genes (g0 a g771)
dados.loc[:, 'g0':'g771'].describe().T['mean'].hist(bins=30)

# %%
# Mostrando histograma de todas as médias de todos os genes (c0 a c99)
dados.loc[:, 'c0':'c99'].describe().T['mean'].hist(bins=50)

# %%
# Plotando o gráfico boxplot utilizando seaborn
sns.boxplot(x='g0', data=dados)

# %%
# Plotando boxplot das colunas g0 e tratamento para compará-las
plt.figure(figsize=(10,8))
sns.boxplot(x='g0', y='tratamento', data=dados)

# %% [markdown]
# # Desafios Aula 2
#
# ### Desafio 1: Ordenar o gráfico countplot
# - reposta nas células de código abaixo
#
# ### Desafio 2: Melhorar a visualização do gráfico, alterando tamanho da fonte do título, mudando/traduzindo o label do eixo x, dentre outras
# - reposta nas células de código abaixo
#
# ### Deasfio 3: Plotar os histogramas com o seaborn
# - reposta nas células de código abaixo
#
# ### Desafio 4: Estudar sobre as estatísticas retornadas pelo método describe()
# - O método describe tem várias possibilidades, pode ser aplicado para variáveis numéricas ou de texto, pode ser utilizado percentuais, mostra medidas de posição central, como média, media, moda, além de medidas de variabilidade como desvio padrão e variância.
#
# ### Desafio 5: Refletir sobre a manipulação do tamanho das visualizações dos gráficos. O que seria um gráfico distorcido? O que ocorre quando "des-distorcemos" um gráfico?
# Acredito que, quando o gráfico está distorcido, ele possui uma resolução muito baixa para os elementos contidos nele e fica difícil a visualização clara das informações, tanto visuais, quanto de textos, principalmente se temos uma fonte muito pequena ou elementos pequenos e próximos entre si. Quando "des-distorcemos" um gráfico, estamos aumentando a resolução de imagem e, se mantivermos a proporção de tamanho, poderemos ter uma imagem mais nítida e legível.
#
# ### Desafio 6: Fazer outras análises com o boxplot e também com o histograma
#
#
# ### Desafio 7: Resumo do que você aprendeu na aula
# - Aprendi a gerar gráfico utilizando a bilbioteca seaborn
# - Aprendi como modificar a imagem do gráfico para melhorar a visualização
# - Aprendi sobre gráficos do tipo barras, histograma e bloxplot
# - Aprendi a fazer análises de dados e comparações entre gráficos
# - Aprendi um pouco mais sobre fármacos e biologia molecular
# - Aprendi a renomear colunas do data frame
# - Aprendi a filtrar dados do data frame
# - Aprendi como gerar medidas estatísticas como média, desvio padrão, dentre outras

# %%
# Desafio 1 => ordernar o gráfico countplot
ax = sns.countplot(x='composto', data=dados_compostos, 
                   order = dados_compostos['composto'].value_counts().index)

# %%
# Desafio 2 => Melhorando a visualização do gráfico
sns.set(font_scale = 1.5)
plt.figure(figsize=(10, 8))
ax = sns.countplot(x='composto', data=dados_compostos, 
                   order = dados_compostos['composto'].value_counts().index)
ax.set_title('Top 5 Compostos')
plt.xlabel('Composto', fontsize=18)
plt.ylabel('Qtde de Registros', fontsize=18)
plt.show()

# %%
# Desafio 3 => plotando histograma utilizando seaborn
sns.displot(dados, x="g0", bins=50)

# %% [markdown]
# # Aula 3 - Correlações, causalidade e relações entre genes

# %%
# Mostrando cruzamento de dados entre as colunas dose e tempo
pd.crosstab(dados['dose'], dados['tempo'])
# Out:
# tempo    24    48    72
# dose
# D1     3886  4354  3907
# D2     3886  3896  3885

# %%
# Mostrando cruzamento de dados entre as colunas tratamento, dose e tempo
# As colunas se referem à classe tratamento e as linhas às classes dose e tempo
pd.crosstab([dados['dose'], dados['tempo']], dados['tratamento'])
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24              301       3585
#      48              343       4011
#      72              307       3600
# D2   24              305       3581
#      48              305       3591
#      72              305       3580

# %%
# Mostrando cruzamento de dados entre as colunas tratamento, dose e tempo
# Agora de forma normalizada, considerando a soma de cada coluna igual a 1
pd.crosstab([dados['dose'], dados['tempo']], dados['tratamento'], normalize=True)
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24         0.012640   0.150542
#      48         0.014403   0.168430
#      72         0.012892   0.151172
# D2   24         0.012808   0.150374
#      48         0.012808   0.150794
#      72         0.012808   0.150332

# %%
# Mostrando cruzamento de dados entre as colunas tratamento, dose e tempo
# De forma normalizada, considerando a soma de cada linha igual a 1
# Agora é possível comparar os dados de uma coluna com outra
pd.crosstab([dados['dose'], dados['tempo']], dados['tratamento'], 
            normalize='index')
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24         0.077458   0.922542
#      48         0.078778   0.921222
#      72         0.078577   0.921423
# D2   24         0.078487   0.921513
#      48         0.078285   0.921715
#      72         0.078507   0.921493

# %%
# Comparando um outro valor (g0, por exemplo) e sendo este valor a média
pd.crosstab([dados['dose'], dados['tempo']], dados['tratamento'], 
            values=dados['g0'], aggfunc='mean')
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24        -0.251760   0.367996
#      48        -0.122773   0.412469
#      72        -0.295271   0.286250
# D2   24         0.010754   0.115253
#      48         0.013174   0.214480
#      72         0.070250   0.253439

# %%
# Gerando gráfico de dispersão para as variáveis g0 e g3
# Cada ponto é uma linha da tabela
# ponto (g0, g3)
sns.scatterplot(x='g0', y='g3', data=dados[['g0', 'g3']])

# %%
# Gerando gráfico de dispersão para as variáveis g0 e g8
# Cada ponto é uma linha da tabela
# ponto (g0, g8)
# resultado indica uma relação inversa
sns.scatterplot(x='g0', y='g8', data=dados[['g0', 'g8']])

# %%
# Gerando gráfico de dispersão
# resultado indica uma relação inversa
# quando um aumenta, o outro diminui
sns.lmplot(data=dados, x='g0', y='g8', line_kws={'color':'red'})

# %%
# Gerando gráfico de dispersão
# Agora separando por tipos de tratamento
# no resultado, parece que a droga está surgindo efeito
# e o controle está "ok"
sns.lmplot(data=dados, x='g0', y='g8', line_kws={'color':'red'}, 
           col='tratamento')

# %%
# Gerando gráfico de dispersão
# Agora separando por tipos de tratamentoe por tipos de tempo
# no resultado, parece que com mais tempo o efeito é um pouco maior
# parece que a curva vai ficando inclinada
# e o controle segue o mesmo, que é como se espera que seja
sns.lmplot(data=dados, x='g0', y='g8', line_kws={'color':'red'}, 
           col='tratamento', row='tempo')

# %%
# Calculando a correção entre todas as colunas que vão de g0 a g711
# Quanto mais próximo de 1 ou -1, mais forte a relação entre elas
# Quanto mais próximo de 0, menor a força de relação
# Quando valor é positivo, a relação é direta
# Quando o valor é negativo, a relação é inversa
# Mas correlação não quer dizer necessariamente uma relação de causalidade
dados.loc[:, 'g0':'g771'].corr()
# Out:
#             g0        g1        g2  ...      g769      g770      g771
# g0    1.000000  0.086032  0.176188  ... -0.127375 -0.514201  0.405908
# g1    0.086032  1.000000 -0.054518  ... -0.006866 -0.095108 -0.032233
# g2    0.176188 -0.054518  1.000000  ...  0.014489 -0.078661  0.103985
# g3    0.011266 -0.027855  0.042633  ... -0.206077 -0.002142  0.058219
# g4    0.403153  0.193647  0.013968  ... -0.172727 -0.363673  0.250713
# ...        ...       ...       ...  ...       ...       ...       ...
# g767 -0.052622 -0.003378 -0.053149  ...  0.065450  0.008603 -0.001136
# g768  0.300241 -0.030756  0.115415  ...  0.079364 -0.382607  0.351651
# g769 -0.127375 -0.006866  0.014489  ...  1.000000  0.135853 -0.083713
# g770 -0.514201 -0.095108 -0.078661  ...  0.135853  1.000000 -0.425063
# g771  0.405908 -0.032233  0.103985  ... -0.083713 -0.425063  1.000000
#
# [772 rows x 772 columns]

# %%
# Gerando matriz de correlação para as colunas de g0 a g50
# mapa de calor entre as correlações
import numpy as np
corr = dados.loc[:, 'g0':'g50'].corr()
mask = np.triu(np.ones_like(corr, dtype=bool))
f, ax = plt.subplots(figsize=(11, 9))
cmap = sns.diverging_palette(230, 20, as_cmap=True)
sns.heatmap(corr, mask=mask, cmap=cmap, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
# Gerando matriz de correlação para as colunas de c0 a c50
# mapa de calor entre as correlações
import numpy as np
corr = dados.loc[:, 'c0':'c50'].corr()
mask = np.triu(np.ones_like(corr, dtype=bool))
f, ax = plt.subplots(figsize=(11, 9))
cmap = sns.diverging_palette(230, 20, as_cmap=True)
sns.heatmap(corr, mask=mask, cmap=cmap, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %% [markdown]
# # Desafios Aula 3
#
# ### Desafio 1: Utilizar o método groupby() para criar a mesma tabela de cruzamento de dados que foi feita com o método crosstab()
# - reposta nas células de código abaixo
#
# ### Desafio 2: Normalizar o crosstab pela coluna
# - reposta nas células de código abaixo
#
# ### Desafio 3: Explorar outros agregadores além da média no crosstab
# - reposta nas células de código abaixo
#
# ### Desafio 4: Explorar o melt para tabela cruzada
# - reposta nas células de código abaixo
#
# ### Desafio 5: Calcular e analisar a correlação entre as colunas g e c (expressões gênicas e tipos celulares). Refletir sobre os efeitos biológicos.
# - gráfico nas células de código mais abaixo
#
# ### Desafio 6: Estudar o código que plota a matriz de correlação (heatmap)
#
# ### Desafio 7: Resumo do que você aprendeu na aula
# - Aprendi a cruzar dados de diferentes colunas
# - Aprendi gerar tabelas com referência cruzadas
# - Aprendi o método crosstab para geração de tabelas
# - Aprendi um pouco mais sobre o seaborn, no caso o método lplot
# - Aprendi o método scatterplot
# - Aprendi o método heatmap
# - Aprendi a gerar gráficos de dispersão
# - Aprendi sobre medidas de correlação
# - Aprendi a analisar dados cruzados entre diferentes colunas
# - Aprendi a gerar e a analisar matriz de correlação (mapa de calor)
# - Aprendi a analisar as diferentes correlações, relações diretas e inversas, relações fortes e fracas
# - Aprendi a diferença entre relações de causalidade e correlações
# - Aprendi um pouco mais sobre biologia genética, entendendo ainda mais o experimento que estamos estudando, compreendendo um pouco mais sobre as expressões gênicas e os tipos celulares
# - Aprendi que os tipos celulares, neste experimento, se referem à viabilidade das células ao receberem a droga

# %%
# Desafio 1 => Utilizar groupby para gerar tabela com referência cruzada
dados.groupby(['dose', 'tempo', 'tratamento']).size().unstack()
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24              301       3585
#      48              343       4011
#      72              307       3600
# D2   24              305       3581
#      48              305       3591
#      72              305       3580

# %%
# Desafio 1 => Utilizar groupby para gerar tabela com referência cruzada
dados.groupby(['dose', 'tempo', 'tratamento'])['g0'].mean().unstack()
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24        -0.251760   0.367996
#      48        -0.122773   0.412469
#      72        -0.295271   0.286250
# D2   24         0.010754   0.115253
#      48         0.013174   0.214480
#      72         0.070250   0.253439

# %%
# Desafio 2 => Normalizando as colunas da tabela gerada pelo crosstab
pd.crosstab([dados['dose'], dados['tempo']], dados['tratamento'], 
            normalize='columns')
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24         0.161308   0.163341
#      48         0.183816   0.182750
#      72         0.164523   0.164024
# D2   24         0.163451   0.163158
#      48         0.163451   0.163614
#      72         0.163451   0.163113

# %%
# Desafio 3 => Explorando outros agregadores no crosstab além da média
# desvio padrão
pd.crosstab([dados['dose'], dados['tempo']], dados['tratamento'], 
            values=dados['g0'], aggfunc='std')
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24         0.751395   1.461954
#      48         0.853396   1.693903
#      72         0.769294   1.458600
# D2   24         0.836626   1.044999
#      48         0.836845   1.315476
#      72         0.878041   1.451532

# %%
# Desafio 3 => Explorando outros agregadores no crosstab além da média
# soma
pd.crosstab([dados['dose'], dados['tempo']], dados['tratamento'], 
            values=dados['g0'], aggfunc='sum')
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24         -75.7799  1319.2648
#      48         -42.1113  1654.4150
#      72         -90.6483  1030.5010
# D2   24           3.2800   412.7202
#      48           4.0180   770.1980
#      72          21.4262   907.3112

# %%
# Desafio 3 => Explorando outros agregadores no crosstab além da média
# valor máximo
pd.crosstab([dados['dose'], dados['tempo']], dados['tratamento'], 
            values=dados['g0'], aggfunc='max')
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24            3.226      9.908
#      48            3.423     10.000
#      72            2.584      9.355
# D2   24            2.601      7.167
#      48            4.335     10.000
#      72            4.670     10.000

# %%
# Desafio 4 => Gerando tabela cruzada com melt()
pd.melt(dados, id_vars=['dose', 'tempo', 'tratamento'], value_vars=['g0'])
# Out:
#       dose  tempo    tratamento variable   value
# 0       D1     24     com_droga       g0  1.0620
# 1       D1     72     com_droga       g0  0.0743
# 2       D1     48     com_droga       g0  0.6280
# 3       D1     48     com_droga       g0 -0.5138
# 4       D2     72     com_droga       g0 -0.3254
# ...    ...    ...           ...      ...     ...
# 23809   D2     24     com_droga       g0  0.1394
# 23810   D2     24     com_droga       g0 -1.3260
# 23811   D2     48  com_controle       g0  0.3942
# 23812   D1     24     com_droga       g0  0.6660
# 23813   D1     72     com_droga       g0 -0.8598
#
# [23814 rows x 5 columns]

# %%
# Desafio 5 => Gerando matriz de correlação para comparar as colunas g e c
colunas_g_c = [f'g{x}' for x in range(0, 26)] + [f'c{x}' for x in range(0, 26)]
dados_g_c = dados.loc[:, colunas_g_c]
corr = dados_g_c.corr()
mask = np.triu(np.ones_like(corr, dtype=bool))
f, ax = plt.subplots(figsize=(11, 9))
cmap = sns.diverging_palette(230, 20, as_cmap=True)
sns.heatmap(corr, mask=mask, cmap=cmap, center=0, 
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %% [markdown]
# # Aula 4 - Merge de dados e análise de resultados

# %%
dados_resultados = pd.read_csv('https://github.com/alura-cursos/imersaodados3/blob/main/dados/dados_resultados.csv?raw=true')
dados_resultados.head()

# A tabela mostra os mecanismos de ação da droga
# Que são a interação bioquímica com o alvo, 
# que pode ser proteína de uma celula ou de um patógeno por exemplo
# Este mecanismo de ação traz 2 informações (separadas por _):
# O alvo e a ação sobre esse alvo
# O alvo pode ser uma enzima
# A ação é o inibidor
# O agonista é o que está potencializando aquele receptor
# O inibidor é o que está inibindo
# Temos agonista e antagonista
# Out:
#              id  ...  wnt_inhibitor
# 0  id_000644bb2  ...              0
# 1  id_000779bfc  ...              0
# 2  id_000a6266a  ...              0
# 3  id_0015fd391  ...              0
# 4  id_001626bd3  ...              0
#
# [5 rows x 207 columns]

# %%
# Na tabela acima, só aparecem zeros, vamos analisar se há diferentes valores
# Mostrando valores únicos de uma coluna
# O resultado é 0 ou 1, que quer dizer que é o resultado dos experimentos da tabela anterior
# Quando mecanismo é ativado, valor 1
# Quando não é ativado, recebe valor 0
dados_resultados['acat_inhibitor'].unique()
# Out:
# array([0, 1])

# %%
# Mostrando contagem das ativações (valor 1) ocorridas nos experimentos
# Quantas vezes cada mecanismo de ação foi ativo em todo o conjunto de dados
# Colunas
contagem_moa = dados_resultados.select_dtypes('int64').sum().sort_values(ascending=False)
contagem_moa
# Out:
# nfkb_inhibitor                                832
# proteasome_inhibitor                          726
# cyclooxygenase_inhibitor                      435
# dopamine_receptor_antagonist                  424
# serotonin_receptor_antagonist                 404
#                                              ...
# protein_phosphatase_inhibitor                   6
# autotaxin_inhibitor                             6
# diuretic                                        6
# erbb2_inhibitor                                 1
# atp-sensitive_potassium_channel_antagonist      1
# Length: 206, dtype: int64

# %%
# Mostrando contagem das ativações por linha
dados_resultados.drop('id', axis=1).sum(axis=1)
# No resultado, a segunda linha deu 0
# Nesses que deu 0, temos que saber se é controle
# Ou às vezes uma droga que não ativou nada
# Pergunta: os controles ativaram algum mecanismo de ação?
# Esperamos que não ative nada
# Out:
# 0        1
# 1        0
# 2        3
# 3        0
# 4        1
#         ..
# 23809    1
# 23810    1
# 23811    0
# 23812    1
# 23813    0
# Length: 23814, dtype: int64

# %%
# Para responder a questão acima, temos que trabalhar com nossas 2 bases de dados
# dados e dados_resultados
# Base de dados com os experimentos e base de dados com os resultados
# Precisamos fazer um merge entre as tabelas

# Primeiro, criar uma nova coluna na tabela para armazenar com os totais de ativos (1)
dados_resultados['n_moa'] = dados_resultados.drop('id', axis=1).sum(axis=1)

# %%
# Depois, criar nova coluna na tabela para armazenar informação se cada linha teve ativo ou não
dados_resultados['ativo_moa'] = (dados_resultados['n_moa'] != 0)
dados_resultados.head()
# Out:
#              id  5-alpha_reductase_inhibitor  ...  n_moa  ativo_moa
# 0  id_000644bb2                            0  ...      1       True
# 1  id_000779bfc                            0  ...      0      False
# 2  id_000a6266a                            0  ...      3       True
# 3  id_0015fd391                            0  ...      0      False
# 4  id_001626bd3                            0  ...      1       True
#
# [5 rows x 209 columns]

# %%
# Depois:
# Combinando as 2 tabelas
# Trazendo todas as colunas da tabela dados
# Trazendo apenas as colunas que interessa da tabela dados_resultados para esta situação
# Utilizando a coluna id como chave primária
dados_combinados = pd.merge(dados, dados_resultados[['id', 'n_moa', 'ativo_moa']], on='id')
dados_combinados.head()
# Out:
#              id tratamento  tempo dose  ...     c98     c99  n_moa  ativo_moa
# 0  id_000644bb2  com_droga     24   D1  ...  0.3801  0.4176      1       True
# 1  id_000779bfc  com_droga     72   D1  ...  0.6077  0.7371      0      False
# 2  id_000a6266a  com_droga     48   D1  ... -1.4080  0.6931      3       True
# 3  id_0015fd391  com_droga     48   D1  ... -0.3876 -0.8154      0      False
# 4  id_001626bd3  com_droga     72   D2  ... -0.3786  0.7125      1       True
#
# [5 rows x 879 columns]

# %%
# Finalmente, respondendo a pergunta:
# Mostrando os totais para a coluna ativo_moa da tabela combinada
# Apenas para os experimentos de controle
dados_combinados.query('tratamento == "com_controle"')['ativo_moa'].value_counts()
# Resultado como o esperado, nenhum controle foi ativado por algum mecanismo de ação
# Out:
# False    1866
# Name: ativo_moa, dtype: int64

# %%
# Outra pergunta:
# Mostrado se houve alguma substância que não ativou o mecanismo de ação
dados_combinados.query('tratamento == "com_droga"')['ativo_moa'].value_counts()
# O resultado mostra os totais mas não é possível a interpretação sem saber por droga
# Pois o alvo pode ser de uma bactéria, ou de um vírus que está no nosso corpo
# Então pode ser interessante que não ative as nossas células humanas
# Mas que haja, tenha algum efeito no patógeno
# Então, no caso, depende da droga
# Out:
# True     14447
# False     7501
# Name: ativo_moa, dtype: int64

# %%
# Gerando gráfico par analisar o gene g0 em relação aos 5 compostos mais frequentes
composto_principal = dados_combinados['composto'].value_counts().index[:6]
plt.figure(figsize=(12, 8))
sns.boxplot(data = dados_combinados.query('composto  in @composto_principal'), y='g0', x = 'composto', hue='ativo_moa')
# Resultado:
# Para uma análise mais apurada, é necessário considerar outras variáveis como dose e tempo
# Necessário quebrar cada boxplot nestas outras variáveis
# Pois este gráfico está mostrando o comportamento de um conjunto de dados
# E se separarmos conforme dose e tempo, por exemplo, 
# Teremos uma melhor visão do que acontece em cada diferente combinação de variáveis

# %% [markdown]
# # Desafios Aula 4
#
# ### Desafio 1: Encontrar o top 10 das ações do MOA (sufixo)
# - reposta nas células de código abaixo
#
# ### Desafio 2: Criar a coluna eh_controle para quando na linha tratamento == com_controle
# - reposta nas células de código abaixo
#
# ### Desafio 3: Criar três colunas para indicar o tempo (24, 48 e 72,com valores true ou false)
# - reposta nas células de código abaixo
#
# ### Desafio 4: Estudar sobre combinações  Data Frames (merge do pandas)
#
# ### Desafio 5: Fazer análise mais detalhada, considerando tempo e dose para comparar as distribuições (Escolher uma droga, talvez a que mais aparece, e comparar com controle)
#
# ### Desafio 6: Descobrir se temos  algum composto  que, dependendo  da configuração do experimento, ativa ou não algum MOA
#
# ### Desafio 7: Descobrir se temos  algum composto  que, dependendo  da configuração do experimento, ativa MOAs diferentes
#
# ### Desafio 8: Resumo do que você aprendeu com os dados
#
# - Aprendi conceitos referentes aos resultados do experimento, os quais estão em outra base de dados, diferente da base de dados com as informações das experimentações.
#
# - Aprendi conceitos de mecanismo de ação, inibidor, alvo, agonista, antagonista
#
# - Aprendi a combinar 2 base de dados através do método merge()
#
# - Aprendi mais sobre exploração e análise de dados

# %%
# Desafio 1 => Mostrando os top 10 das ações MOA

dados_acao = dados_resultados.copy().drop(['id', 'n_moa', 'ativo_moa'], axis = 1)
mapa3={}
for c in dados_acao.columns:
  x = c.split('_')
  mapa3[c] = x[len(x) - 1]
dados_acao.rename(columns=mapa3, inplace=True)
dados_acao.groupby(dados_acao.columns, axis=1).agg(np.max).sum().sort_values(ascending=False).head(10)
# Out:
# inhibitor            7920
# antagonist           3341
# agonist              2240
# blocker               323
# agent                 150
# activator             115
# local                  80
# immunosuppressant      73
# anti-inflammatory      73
# antioxidant            73
# dtype: int64

# %%
# Desafio 2 => Criando a coluna eh_controle para quando tratamento == com_controle

dados_combinados['eh_controle'] = (dados_combinados['tratamento'] == "com_controle")
dados_combinados.head()
# Out:
#              id tratamento  tempo dose  ...     c99  n_moa  ativo_moa  eh_controle
# 0  id_000644bb2  com_droga     24   D1  ...  0.4176      1       True        False
# 1  id_000779bfc  com_droga     72   D1  ...  0.7371      0      False        False
# 2  id_000a6266a  com_droga     48   D1  ...  0.6931      3       True        False
# 3  id_0015fd391  com_droga     48   D1  ... -0.8154      0      False        False
# 4  id_001626bd3  com_droga     72   D2  ...  0.7125      1       True        False
#
# [5 rows x 880 columns]

# %%
# Desafio 3 => Criando as colunas 12, 24, 48 e 72 com valores true ou false

dados_combinados['12'] = (dados_combinados['tempo'] == 12)
dados_combinados['24'] = (dados_combinados['tempo'] == 24)
dados_combinados['48'] = (dados_combinados['tempo'] == 48)
dados_combinados['72'] = (dados_combinados['tempo'] == 72)
dados_combinados.head()
# Out:
#              id tratamento  tempo dose  ...     12     24     48     72
# 0  id_000644bb2  com_droga     24   D1  ...  False   True  False  False
# 1  id_000779bfc  com_droga     72   D1  ...  False  False  False   True
# 2  id_000a6266a  com_droga     48   D1  ...  False  False   True  False
# 3  id_0015fd391  com_droga     48   D1  ...  False  False   True  False
# 4  id_001626bd3  com_droga     72   D2  ...  False  False  False   True
#
# [5 rows x 884 columns]

# %% [markdown]
# # Aula 5 - Machine Learning, Sci-kit learning e desafios envolvidos

# %%
#
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

x = dados_combinados.select_dtypes('float64')
y = dados_combinados['ativo_moa']
x_treino, x_teste, y_treino, y_teste = train_test_split(x, y, test_size = 0.2, stratify=y, random_state=639)

modelo_rlog = LogisticRegression(max_iter=1000)
modelo_rlog.fit(x, y)
modelo_rlog.score(x_teste, y_teste)
# Out:
# 0.6804534956959899

# %%
from sklearn.dummy import DummyClassifier
from sklearn.metrics import accuracy_score


modelo_dummy = DummyClassifier('most_frequent')
modelo_dummy.fit(x_treino, y_treino)
previsao_dummy = modelo_dummy.predict(x_teste)
accuracy_score(y_teste, previsao_dummy)
# Out:
# 0.6067604450976275

# %%
dados_combinados['ativo_moa'].value_counts(normalize = True)
# Out:
# True     0.60666
# False    0.39334
# Name: ativo_moa, dtype: float64

# %%
from sklearn.tree import DecisionTreeClassifier

x = dados_combinados.select_dtypes('float64')
y = dados_combinados['ativo_moa']
x_treino, x_teste, y_treino, y_teste = train_test_split(x, y, test_size = 0.2, stratify=y, random_state=639)

modelo_arvore = DecisionTreeClassifier(max_depth=3)
modelo_arvore.fit(x_treino, y_treino)
modelo_arvore.score(x_teste, y_teste)
# Out:
# 0.614948561830779

# %%
from sklearn import tree

fig, ax = plt.subplots(figsize=(15,10), facecolor='k')
tree.plot_tree(modelo_arvore,ax=ax,fontsize=10,rounded=True,filled=True,
               feature_names=x_treino.columns,class_names=['Não Ativado', 'Ativado'])
plt.show()

# %%
from sklearn import tree

x = dados_combinados.select_dtypes('float64')
y = dados_combinados['ativo_moa']
x_treino, x_teste, y_treino, y_teste = train_test_split(x, y, test_size = 0.2, stratify=y, random_state=639)

teste=[]
treino=[]
for i in range(1,15):
  modelo_arvore = DecisionTreeClassifier(max_depth=i)
  modelo_arvore.fit(x_treino, y_treino)
  teste.append(modelo_arvore.score(x_teste, y_teste))
  treino.append(modelo_arvore.score(x_treino, y_treino))

# %%
teste
# Out:
# [0.6067604450976275,
#  0.6057106865420954,
#  0.6153684652529918,
#  0.6252361956749948,
#  0.6235565819861432,
#  0.6191475960529078,
#  0.6172580306529498,
#  0.6216670165861852,
#  0.6222968717195045,
#  0.6172580306529498,
#  0.6111694310308629,
#  0.6071803485198405,
#  0.6141087549863531,
#  0.6078102036531597]

# %%
treino
# Out:
# [0.6066348223190384,
#  0.6073696918796914,
#  0.6197050023620807,
#  0.6331426171854496,
#  0.6348748097212745,
#  0.646685213374626,
#  0.6581806729305548,
#  0.6719332318513463,
#  0.6877854180882893,
#  0.7028502440816755,
#  0.7232691197312477,
#  0.7399086662117474,
#  0.7570206288383812,
#  0.7732927405385545]

# %%
sns.lineplot(x=range(1,15), y=teste, label='teste')
sns.lineplot(x=range(1,15), y=treino, label='treino')

# %%
pd.get_dummies(dados_combinados['tratamento'])
# Out:
#        com_controle  com_droga
# 0                 0          1
# 1                 0          1
# 2                 0          1
# 3                 0          1
# 4                 0          1
# ...             ...        ...
# 23809             0          1
# 23810             0          1
# 23811             1          0
# 23812             0          1
# 23813             0          1
#
# [23814 rows x 2 columns]

# %%
pd.get_dummies(dados_combinados, columns=['tratamento','dose', 'tempo'])
# Out:
#                  id   composto      g0  ...  tempo_24  tempo_48  tempo_72
# 0      id_000644bb2  b68db1d53  1.0620  ...         1         0         0
# 1      id_000779bfc  df89a8e5a  0.0743  ...         0         0         1
# 2      id_000a6266a  18bb41b2c  0.6280  ...         0         1         0
# 3      id_0015fd391  8c7f86626 -0.5138  ...         0         1         0
# 4      id_001626bd3  7cbed3131 -0.3254  ...         0         0         1
# ...             ...        ...     ...  ...       ...       ...       ...
# 23809  id_fffb1ceed  df1d0a5a1  0.1394  ...         1         0         0
# 23810  id_fffb70c0c  ecf3b6b74 -1.3260  ...         1         0         0
# 23811  id_fffc1c3f4  cacb2b860  0.3942  ...         0         1         0
# 23812  id_fffcb9e7c  8b87a7a83  0.6660  ...         1         0         0
# 23813  id_ffffdd77b  972f41291 -0.8598  ...         0         0         1
#
# [23814 rows x 888 columns]

# %%
from sklearn.ensemble import RandomForestClassifier

x = dados_combinados.drop(['id', 'n_moa', 'ativo_moa', 'composto'], axis=1)
x = pd.get_dummies(x, columns=['tratamento','dose', 'tempo'])
y = dados_combinados['ativo_moa']
x_treino, x_teste, y_treino, y_teste = train_test_split(x, y, test_size = 0.2, stratify=y, random_state=639)

modelo_randomforest = RandomForestClassifier()
modelo_randomforest.fit(x_treino, y_treino)
modelo_randomforest.score(x_teste, y_teste)
# Out:
# 0.6907411295402057

# %% [markdown]
# # Desafios Aula 5
#
# ### Desafio 1: Tente outros modelos ou mude os parâmetros dos modelos que testamos em aula
#
# ###Desafio 2: Estude a documentação do Sklearn
#
# ###Desafio 3: Pesquisar o fluxograma 'Escolhendo o melhor modelo'
#
# ###Desafio 4: Teste outras problemas (perguntas). 0, 1 ou +
#
# ###Desafio 5: Escolha a droga mais utilizada e tente criar um modelo para prever este label
#
# ###Desafio 6: Resumo do que você aprendeu
